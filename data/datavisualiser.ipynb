# %%
# import the pacakges
import sklearn
import pandas as pd
import numpy as np

# for splitting
from sklearn.model_selection import train_test_split

# for imputation
from feature_engine.imputation import RandomSampleImputer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
import feature_engine.imputation as mdi

# for visuals 
import math
import matplotlib.pyplot as plt
import seaborn as sns

# for statistical analysis
import scipy.stats as stats

# for encoding
from feature_engine.encoding import RareLabelEncoder
from feature_engine.encoding import OneHotEncoder
from feature_engine.encoding import OrdinalEncoder
from feature_engine.encoding import MeanEncoder
from feature_engine.encoding import CountFrequencyEncoder
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# for outlier handling
from feature_engine.outliers import Winsorizer

# for interaction
import ipywidgets as widgets
from IPython.display import display

# for numerical transformation
from sklearn.preprocessing import FunctionTransformer
from feature_engine.transformation import YeoJohnsonTransformer
from feature_engine.transformation import LogTransformer
from feature_engine.transformation import ReciprocalTransformer
from feature_engine.transformation import PowerTransformer
from feature_engine.transformation import BoxCoxTransformer

# for discretization
from sklearn.preprocessing import KBinsDiscretizer
from feature_engine.discretisation import EqualWidthDiscretiser
from feature_engine.discretisation import EqualFrequencyDiscretiser
from feature_engine.discretisation import EqualFrequencyDiscretiser

# for feature engine
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.decomposition import PCA

# for linear regression modelling
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# for classification modelling
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# remove warning
import warnings
warnings.filterwarnings('ignore')

# %%
# Here we are taking the DFS dictionary. Read README.MD to understand!
from dataextract import dfs

# To assign a variable to a table, use the format below. Key names are as follows:
# "devicedata", "devices", "devicesensors", "devicetypes",
# "errors", "sensordata", "sensors", "users"
# Assigning all key values in the dfs dictionary to DataFrames
devicedata_df = dfs["devicedata"]

devices_df = dfs["devices"] # contains the device IDs, names, type of sensors (? <- check this)
# device description e.g. NP DS Rack 1 Env Unit, and the status (online or offline)
devicesensors_df = dfs["devicesensors"]

devicetypes_df = dfs["devicetypes"]

errors_df = dfs["errors"]

sensordata_df = dfs["sensordata"] # tells you what data is under which sensor ID. Sensor ID 6 is CO2.

sensors_df = dfs["sensors"] # the different sensor IDs

users_df = dfs["users"]
# Out:
# Loaded devicedata with 100000 rows.
# Loaded devices with 38 rows.
# Loaded devicesensors with 245 rows.
# Loaded devicetypes with 8 rows.
# Loaded errors with 100000 rows.
# Loaded sensordata with 100000 rows.
# Loaded sensors with 19 rows.
# Loaded users with 6 rows.

# %%
# sensordata_df.hist(figsize=(15, 10), bins=20, edgecolor='black')
# plt.suptitle('Distribution of Numerical Features')
# plt.show()

print(dfs["users"])
# Out:
# {'devicedata':        devicedataid  deviceid   dataid  crcvalid  crcnegative  \
# 0           8913773        16  8913773     False         True
# 1           8913774        16  8913774     False         True
# 2           8913775         3  8913775      True        False
# 3           8913776         9  8913776     False        False
# 4           8913777         9  8913777     False        False
# ...             ...       ...      ...       ...          ...
# 99995       9004199        14  9004199     False         True
# 99996       9004200        13  9004200     False         True
# 99997       9004201        13  9004201     False         True
# 99998       9004202        13  9004202     False         True
# 99999       9004203        13  9004203     False         True
#
#           devicetimestamp                dbtimestamp
# 0     2024-08-22 12:40:09 2024-08-22 12:40:10.157779
# 1     2024-08-22 12:40:09 2024-08-22 12:40:10.162774
# 2     2024-08-22 12:40:10 2024-08-22 12:40:10.940386
# 3     2024-08-22 12:40:12 2024-08-22 12:40:13.207032
# 4     2024-08-22 12:40:12 2024-08-22 12:40:13.210969
# ...                   ...                        ...
# 99995 2024-08-22 20:18:20 2024-08-22 20:18:21.096022
# 99996 2024-08-22 20:18:20 2024-08-22 20:18:21.601945
# 99997 2024-08-22 20:18:20 2024-08-22 20:18:21.605883
# 99998 2024-08-22 20:18:20 2024-08-22 20:18:21.614694
# 99999 2024-08-22 20:18:21 2024-08-22 20:18:22.232207
#
# [100000 rows x 7 columns], 'devices':     deviceid                    devicename  devicetypeid  \
# 0          3                  NP DS Rack 0             2
# 1          4                  NP DS Rack 1             1
# 2         10                        NDS016             3
# 3         20                        RC4 03             3
# 4          5         Centre 03 West Tank 0             4
# 5          1         Centre 03 West Tank 0             3
# 6         15         Centre 03 West Tank 0             5
# 7         22  RC4 Compost Tank Environment             6
# 8         25              TRF Plant Pot 01             7
# 9         24      TRF Plant Environment 01             6
# 10        19                        RC4 02             3
# 11        21                        RC4 04             3
# 12        18                        RC4 01             3
# 13        27              TRF Plant Pot 03             7
# 14        31                         NUS01             3
# 15        35                         NUS05             3
# 16        34                         NUS04             3
# 17        32                         NUS02             3
# 18        26              TRF Plant Pot 02             7
# 19        16                        NDS002             3
# 20        23                          TEST             4
# 21        33                         NUS03             3
# 22        17                        NDS015             3
# 23        37            TRF Earthie Wormie             3
# 24        36       TRF The Little Red Farm             3
# 25        38  Centre 03 West Solar Monitor             8
# 26         9                        NDS006             3
# 27        13                        NDS012             5
# 28         8                        NDS005             3
# 29        14                        NDS009             4
# 30        12                        NDS011             5
# 31        29                NDS002 TEST 02             3
# 32         7                        NDS004             3
# 33         6                        NDS008             4
# 34         2                        NDS007             3
# 35        28                NDS002 TEST 01             3
# 36        30                NDS002 TEST 03             3
# 37        11                        NDS010             5
#
#                                     devicedescription  \
# 0                               NP DS Rack 0 Env Unit
# 1                               NP DS Rack 1 Env Unit
# 2         NP DS Group A Tank NDS016, moved to NUS RC4
# 3                    Originally Centre 03 West Tank 3
# 4                           Centre 03 West Tank 0 New
# 5                               Centre 03 West Tank 0
# 6                       Centre 03 West Tank 0 New New
# 7   Originally Centre 03 West Compost Tank Environ...
# 8                                                None
# 9                                                None
# 10                   Originally Centre 03 West Tank 2
# 11                   Originally Centre 03 West Tank 4
# 12       Originally Centre 03 West Tank 0 New New New
# 13                                               None
# 14                        NUS Composting Workshop RC4
# 15                   NUS Composting Workshop NUS SAVE
# 16                       NUS Composting Workshop RVRC
# 17                   NUS Composting Workshop NUS SAVE
# 18                                               None
# 19                          NP DS Group E Tank NDS002
# 20                                               TEST
# 21              NUS Composting Workshop Pioneer House
# 22                          NP DS Group D Tank NDS015
# 23                                   Soil Sensor 0X02
# 24                                   Soil Sensor 0X01
# 25                                               None
# 26                          NP DS Group A Tank NDS006
# 27                          NP DS Group B Tank NDS012
# 28                          NP DS Group A Tank NDS005
# 29                          NP DS Group C Tank NDS009
# 30                          NP DS Group B Tank NDS011
# 31     NDS002 Tank. Testing three soil sensor models.
# 32                          NP DS Group A Tank NDS004
# 33                          NP DS Group C Tank NDS008
# 34                          NP DS Group C Tank NDS007
# 35     NDS002 Tank. Testing three soil sensor models.
# 36     NDS002 Tank. Testing three soil sensor models.
# 37                          NP DS Group B Tank NDS010
#
#                                           bearertoken  online  locationid
# 0   95afbf7eb7f197bfb462376178c9211dc2ef9f55ea4d72...    True           4
# 1   af806036198362c67beb0169e53afcf0a1f4215bda5567...    True           4
# 2   d5dc1918e7fd4a811e08d4320b7a648b9145c7cb0b0390...    True           1
# 4             5          Compost Tank Unit with soil sensor, SCD41
# 5             6                 Environmental Unit with SCD41 only
# 6             7            Plant Unit with single soil sensor only
# 7             8                                      Solar Monitor, 'errors':        errorid  deviceid  error     errormessage     devicetimestamp  \
# 0            1         5      5  Data not ready. 2024-07-14 19:58:43
# 1            2         5      5  Data not ready. 2024-07-14 19:58:46
# 2            3         5      5  Data not ready. 2024-07-14 19:58:49
# 3            4         5      5  Data not ready. 2024-07-14 19:58:50
# 4            5         5      5  Data not ready. 2024-07-14 19:58:53
# ...        ...       ...    ...              ...                 ...
# 99995   100000         4      5  Data not ready. 2024-07-30 22:59:08
# 99996   116361         4      5  Data not ready. 2024-07-31 13:33:15
# 99997   118780         4      5  Data not ready. 2024-07-31 15:43:05
# 99998   118781         4      5  Data not ready. 2024-07-31 15:43:10
# 99999   118782         4      5  Data not ready. 2024-07-31 15:43:13
#
#                      dbtimestamp
# 0     2024-07-14 19:58:43.608129
# 1     2024-07-14 19:58:46.553639
# 2     2024-07-14 19:58:49.525356
# 3     2024-07-14 19:58:50.999883
# 4     2024-07-14 19:58:54.049973
# ...                          ...
# 99995 2024-07-30 22:59:08.950509
# 99996 2024-07-31 13:33:15.985297
# 99997 2024-07-31 15:43:06.233944
# 99998 2024-07-31 15:43:11.233504
# 99999 2024-07-31 15:43:14.613362
#
# [100000 rows x 6 columns], 'sensordata':        dataid  sensorid  value
# 0      567074         6   75.0
# 1      567075         7  135.0
# 2      567076         9   22.8
# 3      567077         8   29.1
# 4      567078        11  706.0
# ...       ...       ...    ...
# 99995  666822         6   75.0
# 99996  666823         7  133.0
# 99997  666824         4  415.0
# 99998  666825         4  300.0
# 99999  666826         5  297.0
#
# [100000 rows x 3 columns], 'sensors':     sensorid            sensor  \
# 0          5              MQ-4
# 1          6              MQ-7
# 2          7            MQ-135
# 3          3          Humidity
# 4          8  Soil Temperature
# 5          4               CH4
# 6          1               CO2
# 7          2   Air Temperature
# 8         11           Soil EC
# 9          9     Soil Moisture
# 10        10           Soil pH
# 11        14    Soil Potassium
# 12        12     Soil Nitrogen
# 13        13   Soil Phosphorus
# 14        15     Solar Voltage
# 15        16   Battery Voltage
# 16        17     Solar Current
# 17        18   Battery Current
# 18        19      Load Current
#
#                                     sensordescription
# 0                    Environmental - CH4, Natural Gas
# 1                                  Environmental - CO
# 2   Environmental - NH3, NOx, Alcohol, Benzene, Sm...
# 3             Environmental - SCD41 Relative Humidity
# 4                                  Soil - Temperature
# 5    Environmental - DFRobot Fermion MEMS Methane CH4
# 6                           Environmental - SCD41 CO2
# 7                   Environmental - SCD41 Temperature
# 8                                           Soil - EC
# 9                                     Soil - Moisture
# 10                                          Soil - PH
# 11                                   Soil - Potassium
# 12                                    Soil - Nitrogen
# 13                                  Soil - Phosphorus
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None  , 'users':    userid       username               userorg  \
# 0       1           Seth          TinkerThings
# 1       2  NP DS Group C  Ngee Ann Polytechnic
# 2       3  NP DS Group A  Ngee Ann Polytechnic
# 3       5  NP DS Group E  Ngee Ann Polytechnic
# 4       4  NP DS Group B  Ngee Ann Polytechnic
# 5       6  NP DS Group D  Ngee Ann Polytechnic
#
#                    userdescription
# 0                              yes
# 1  hannah, trinity, clayton, bryan
# 2         chun fai, claudia, fionn
# 3                           walter
# 4                    Markell, Ryan
# 5                            leroy  }
